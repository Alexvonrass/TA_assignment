# %%
from feature_engineering import *
# Out:
# (47007, 10) (298, 3) 31179 13
# function [feat_eng_time_delta] finished in 3 ms
# function [feat_eng_time_cat] finished in 4 ms
# function [feat_eng_user_searches] finished in 27391 ms
# function [feat_eng_origin_searches] finished in 505 ms
# function [feat_eng_total_searches] finished in 202 ms
# (47007, 41)

# %%
model.eve['ts'].dt.date.unique()[-3]
# Out:
# datetime.date(2017, 4, 30)

# %%
model.eve[model.eve['ts'].dt.date == model.eve['ts'].dt.date.unique()[-3]].head()
# Out:
#                        ts event_type user_id  date_from    date_to origin  \
# 14183 2017-04-30 00:00:05     search  cccc5b 2017-05-17 2017-05-20    FRA
# 12161 2017-04-30 00:00:09     search  29fc17 2017-05-16 2017-05-19    MUC
# 15683 2017-04-30 00:00:10     search  3e7f4b 2017-09-03 2017-09-17    PAR
# 28310 2017-04-30 00:00:13     search  bf72c3 2017-05-18 2017-05-21    PAR
# 34115 2017-04-30 00:00:18     search  bc00b6 2017-05-03 2017-05-03    MUC
#
#       destination  num_adults  num_children  target  ...  \
# 14183         MOW           2             0       0  ...
# 12161         IEV           1             0       0  ...
# 15683         LIS           1             0       0  ...
# 28310         OPO           1             0       0  ...
# 34115         LON           1             0       0  ...
#
#        total_target_mean_last_2h  total_target_mean_last_2h_ratio  \
# 14183                       21.0                         0.552632
# 12161                       21.0                         0.552632
# 15683                       21.0                         0.552632
# 28310                       21.0                         0.552632
# 34115                       21.0                         0.552632
#
#        total_searches_last_6h  total_searches_last_6h_ratio  \
# 14183                  3346.0                      0.510528
# 12161                  3346.0                      0.510450
# 15683                  3346.0                      0.510372
# 28310                  3346.0                      0.510372
# 34115                  3346.0                      0.510294
#
#        total_target_mean_last_6h  total_target_mean_last_6h_ratio  \
# 14183                       55.0                         0.544554
# 12161                       55.0                         0.544554
# 15683                       55.0                         0.544554
# 28310                       55.0                         0.544554
# 34115                       55.0                         0.544554
#
#        total_searches_last_1d  total_searches_last_1d_ratio  \
# 14183                  8650.0                      0.506975
# 12161                  8649.0                      0.506886
# 15683                  8650.0                      0.506915
# 28310                  8648.0                      0.506828
# 34115                  8648.0                      0.506798
#
#        total_target_mean_last_1d  total_target_mean_last_1d_ratio
# 14183                      145.0                         0.521583
# 12161                      145.0                         0.521583
# 15683                      145.0                         0.521583
# 28310                      145.0                         0.521583
# 34115                      145.0                         0.521583
#
# [5 rows x 41 columns]

# %%
from feature_engineering import *

class ProcessingAndModel():
    
    def __init__(self, events_csv, geo_csv, lgb_params):
        self.eve = pd.read_csv(events_csv, parse_dates=['ts','date_from', 'date_to'], dtype={
        'event_type':'category', 'origin':'str', 'destination':'str', 'user_id':'category'
        , 'num_adults':np.int32, 'num_children':np.int32})
        self.geo = pd.read_csv(geo_csv).groupby('iata_code').agg({'lat':'mean', 'lon':'mean'}).reset_index()
        self.lgb_params = np.load(lgb_params, allow_pickle=True).item()
        self.feat_eng_steps = [feat_eng_time_cat, feat_eng_time_delta
                               ,feat_eng_user_searches, feat_eng_origin_searches, feat_eng_total_searches]
        self.time_windows = ['300s', '1h', '2h', '6h', '1d']
        self.features = ['num_adults', 'distance_km', 'trip_length', 'total_target_mean_last_300s_ratio']
        self.val_days = 3
        self.upsampling = 5
        
        
    def feature_eng(self):
        self.eve['target']=np.int32(self.eve['event_type']=='book')
        self.eve.sort_values(by = 'ts', inplace=True)
        
        # Feature engineering, some steps require a 'time_window' argument, those have '_tw' in their name
        for step in self.feat_eng_steps:
            if '_tw' in step.__name__:
                self.eve = step(self.eve, self.time_windows)
            else:
                self.eve = step(self.eve)
                
        print("Dataframe shape is {}, it has {} unique user_ids, and there are {} distinct days in the dataset".format(
        self.eve.shape, self.eve['user_id'].nunique(), (self.eve['ts'].max() - self.eve['ts'].min()).days))
                
        # Drop the first day since time-window based features will be NA for these
        self.eve = self.eve[self.eve['ts'].dt.date > self.eve['ts'].min().date()+pd.Timedelta('1d')]
        
        # Use several last days for validation iteratively, ie use all data to predict the next day
        for val_day in self.eve['ts'].dt.date.unique()[-self.val_days:]:
            # Split the data into train and val, upsample positive examples in train but not val
            train = self.eve[(self.eve['ts'].dt.date < val_day)].copy()
            train =  pd.concat([train]+[train[train['target']==1].copy()]*self.upsampling, axis=0)
            val = self.eve[(self.eve['ts'].dt.date == val_day)].copy()
            
            # Encode origin and dest as categories separately
            train['origin'] = train['origin'].astype('category')
            train['origin_int'] = train['origin'].cat.codes
            val['origin'] = pd.Categorical(val['origin'], train['origin'].cat.categories)
            val['origin_int'] = val['origin'].cat.codes

            train['destination'] = train['destination'].astype('category')
            train['dest_int'] = train['destination'].cat.codes
            val['destination'] = pd.Categorical(val['destination'], train['destination'].cat.categories)
            val['dest_int'] = val['destination'].cat.codes
            
            cat = ['hour', 'day_of_week', 'origin_int', 'dest_int']
            cat = [c for c in cat if c in self.features]
            
            lgbset_train = lgb.Dataset(train[features], train['target'], feature_name=self.features, categorical_feature=cat)
            lgbset_val = lgb.Dataset(val[features], val['target'], feature_name=self.features, categorical_feature=cat)
            bst = lgb.train(self.lgb_params, lgbset_train, valid_sets = [lgbset_train, lgbset_val], num_boost_round = 50)
            self.model = bst
        
        
    def build_model(self):
        pass
    
    # This was not part of the assignment, but in production we would use the model and parameters stored in this object to score new data
    def score(self, new_events_csv):
        pass
    
    
model = ProcessingAndModel(r'input/events.csv', r'input/iata.csv', 'lgb_params_v0.npy')
model.feature_eng()
# Out:
# function [feat_eng_time_cat] finished in 4 ms
# function [feat_eng_time_delta] finished in 3 ms
# function [feat_eng_user_searches] finished in 27683 ms
# function [feat_eng_origin_searches] finished in 490 ms
# function [feat_eng_total_searches] finished in 154 ms
# Dataframe shape is (47007, 41), it has 31179 unique user_ids, and there are 13 distinct days in the dataset
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-4b3c468b2cd7> in <module>
#      69
#      70 model = ProcessingAndModel(r'input/events.csv', r'input/iata.csv', 'lgb_params_v0.npy')
# ---> 71 model.feature_eng()
#      72
#
# <ipython-input-33-4b3c468b2cd7> in feature_eng(self)
#      55             cat = [c for c in cat if c in self.features]
#      56
# ---> 57             lgbset_train = lgb.Dataset(train[features], train['target'], feature_name=self.features, categorical_feature=cat)
#      58             lgbset_val = lgb.Dataset(val[features], val['target'], feature_name=self.features, categorical_feature=cat)
#      59             bst = lgb.train(self.lgb_params, lgbset_train, valid_sets = [lgbset_train, lgbset_val], num_boost_round = 50)
#
# NameError: name 'lgb' is not defined

# %%
feat

# %%
model.eve.shape

# %%
params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'num_leaves': 32,
    'max_depth': 6,
    'learning_rate': 0.05,
    'feature_fraction': 0.7,
    'bagging_fraction': 0.7,
    'pos_bagging_fraction':1.,
    'neg_bagging_fraction': 0.2,
    'min_sum_hessian_in_leaf ': 1e1,
    'min_data_in_leaf': 100,
    'lambda_l1':2e1,
    'min_gain_to_split':1e1,
    'bagging_freq': 5,
    'metric':'auc',
    'verbose': 0
}

# %%
import numpy as np
np.save('lgb_params_v0.npy', params)

# %%
a = np.load('lgb_params_v0.npy', allow_pickle=True).item()
